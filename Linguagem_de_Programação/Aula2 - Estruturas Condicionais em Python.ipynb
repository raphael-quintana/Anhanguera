# %%
# Qual faixa vocẽ está?

idade = 15

if idade < 18:
    (print("Menor de Idade"))
elif idade >= 19 and idade < 65:
    print("Adulto")
else:
    print("Idoso")
# Out:
# Menor de Idade

# %%
#Máquina de Venda Automática do Cinema#


#Solicita a idade do cliente
idade = int(input("Por favor, digite sua idade: "))


#Faz a verificação de idade, recomendando o filme mais apropriado.
if idade < 12:
    print("Recomendamos o filme infantil FILME1.")
elif 12 <= idade < 18:
    print("Recomendamos o filme adolescente FILME2.")
else:
    print("Recomendamos o emocionante FILME3.")

#Verifica disponibilidade de ingressos#
quantidade_ingressos = 24

if quantidade_ingressos > 0:
    print("Ingressos disponíveis. Divirta-se!")
else:
    print("Desulpe, acabaram os ingressos.")
# Out:
# Recomendamos o emocionante FILME3.
# Ingressos disponíveis. Divirta-se!
