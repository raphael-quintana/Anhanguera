# %%
#Explorando o desenvolvimento web com Python

#Criando uma página HTML usando Python

html_code = """
<!DOCTYPE html>
<html>
<head>
  <title>Exemplo de Front-End com Python</title>
</head>
<body>
  <h1>Olá, mundo!</h1>
  <p>Esta é uma página web criada usando Python no VS Code.</p>
</body>
</html>
"""

# %%
#Utilizando o IPython para exibir o HTML
from IPython.display import HTML
HTML(html_code)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Exemplo de Front-End com Python</title>
# </head>
# <body>
#   <h1>Olá, mundo!</h1>
#   <p>Esta é uma página web criada usando Python no VS Code.</p>
# </body>
# </html>

# %%
#Explorando o back-end

#Criando um servidor simples com Flask

#Importando o flask
from flask import Flask

#Criando a aplicação Flask
app = Flask(__name__)

#Rota para a página inicial
@app.route("/")
def hello():
    return "Bem-vindo ao back-end simples com Flask!"

#Executa a aplicação no host e na porta especificada
if __name__ == "__main__":
    app.run(host="localhost", port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [11/Apr/2026 20:04:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Apr/2026 20:04:03] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Apr/2026 20:04:30] "GET / HTTP/1.1" 200 -
