# %%
x = 10
nome = "aluno"
nota = 8.5
fez_inscricao = True


print(type(x))
print(type(len(nome)))
print(type((nota)))
print(type((fez_inscricao)))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
nome = input("Digite seu nome:")



print(f"Olá {nome}! Seja bem vindo ao curso")
# Out:
# Olá Raphael! Seja bem vindo ao curso
