# %%
#Explorando módulos e bibliotecas

#Primeiro modo de uso da biblioteca math

import math

math.sqrt(25)
#math.log2(1024)
#math.cos(45)
# Out:
# 5.0

# %%
#Segundo modo 

import math as m

m.sqrt(25)
#m.log2(1024)
#m.cos(45)
# Out:
# 5.0

# %%
#Terceiro modo, importando somente o que vamos usar da biblioteca math

from math import sqrt, log2, cos

m.sqrt(25)
#m.log2(1024)
#m.cos(45)
# Out:
# 5.0

# %%
#Explorando a biblioteca Matplotlib

#Importando a biblioteca
import matplotlib.pyplot as plt

#Dados
x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 3, 5]

#Criar um gráfico de linha
plt.plot(x, y) #plt.bar para gráficos de barra

#Adicionar rótulos nos eixos
plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")

#Adicionando um título ao gráfico
plt.title("Exemplo de gráfico de linha")

#Mostrar o gráfico
plt.show()
